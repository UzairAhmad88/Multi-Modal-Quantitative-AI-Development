# %% [markdown]
# # Quant AI Research — Notebook 04: Model Explainability & SHAP Feature Attribution
#
# Generates global SHAP summary values, local force plot attributions, and modality contributions.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('../../'))
from src.research.explainability import ModelExplainer

fi = {'momentum_20d': 0.35, 'sentiment_score': 0.30, 'volatility_20d': 0.20, 'pe_ratio': 0.15}
explainer = ModelExplainer(model=None, feature_names=list(fi.keys()))
modality = explainer.compute_modality_attribution(fi)
print('Modality Breakdown:', modality)
