# %% [markdown]
# # Portfolio Research — Notebook 03: Minimum Variance Optimization
#
# Solves quadratic program minimizing total portfolio variance subject to position constraints.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('../../'))
import pandas as pd, numpy as np
from src.portfolio.optimizers import MinimumVarianceOptimizer

symbols = ['AAPL', 'NVDA', 'MSFT']
exp_rets = pd.Series([0.03, 0.05, 0.02], index=symbols)
cov_df = pd.DataFrame([[0.04, 0.01, 0.005], [0.01, 0.09, 0.01], [0.005, 0.01, 0.025]], index=symbols, columns=symbols)
opt = MinimumVarianceOptimizer()
w = opt.optimize(exp_rets, cov_df)
print('Minimum Variance Weights:', w.to_dict())
