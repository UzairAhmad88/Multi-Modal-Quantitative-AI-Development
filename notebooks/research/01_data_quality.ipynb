# %% [markdown]
# # Quant AI Research — Notebook 01: Data Quality & Point-in-Time Integrity Audit
#
# This notebook verifies data completeness, missingness, timestamp alignment, and point-in-time filing dates to eliminate look-ahead leakage.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('../../'))
import pandas as pd
import numpy as np
from src.data.market_loader import load_market_data
from src.data.fundamental_loader import load_fundamentals

market_df = load_market_data('AAPL')
print(f'Market records: {len(market_df)}')
print('Missing values:', market_df.isnull().sum().to_dict())
