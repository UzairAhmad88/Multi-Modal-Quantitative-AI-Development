# %% [markdown]
# # Quant AI Research — Notebook 07: Parameter, Transaction Cost & Slippage Sensitivity Matrix
#
# Evaluates strategy performance across 0–100 bps transaction fees and 0–50 bps slippage drag.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('../../'))
from src.research.robustness import RobustnessTester

def mock_bt(p):
    c = p.get('transaction_cost_bps', 10.0)
    return {'sharpe': max(0.0, 1.8 - c/50.0), 'cagr': 0.18 - c/1000.0, 'max_drawdown': -0.11}

tester = RobustnessTester(mock_bt)
res = tester.test_cost_sensitivity()
print(res)
