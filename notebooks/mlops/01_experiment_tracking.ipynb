# %% [markdown]
# # Phase 8 Notebook 01: Experiment Tracking & Management
# This notebook demonstrates how to create, track, run, and log quantitative AI experiments using `ExperimentManager` and `FullResearchPipeline`.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parents[1]))

from src.mlops.experiments import ExperimentManager
from src.mlops.pipelines import FullResearchPipeline

exp_mgr = ExperimentManager()
exp = exp_mgr.create_experiment(name="LSTM_MultiModal_Alpha", description="Evaluating LSTM multimodal alpha strategy")
print("Created Experiment:", exp["experiment_id"])

# %%
pipeline = FullResearchPipeline(config_path="../../configs/experiments/multimodal.yaml")
run_res = pipeline.run()
print("Run Execution Completed. Run ID:", run_res["run_id"])
