# %% [markdown]
# # Quant AI Research — Notebook 08: Historical Stress Periods & Hypothetical Market Shocks
#
# Simulates portfolio response during 2020 COVID crash, 2022 rate hikes, and -20% market shocks.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('../../'))
import pandas as pd
import numpy as np
from src.research.stress_testing import StressTester

rets = pd.Series(np.random.normal(0.0008, 0.012, 500))
st = StressTester(rets)
shocks = st.run_hypothetical_shocks()
print('Hypothetical Shocks:', shocks)
