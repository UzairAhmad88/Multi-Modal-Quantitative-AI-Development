# %% [markdown]
# # Phase 8 Notebook 03: End-to-End Lineage Traceability & Auditability
# Demonstrates how to trace an out-of-sample backtest or live trading signal back to its precise dataset version, feature version, config snapshot, and git commit hash.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parents[1]))

from src.mlops.lineage import LineageTracker
from src.mlops.reproducer import ExperimentReproducer

tracker = LineageTracker()
dag = tracker.get_lineage("EXP-RUN-001")
print("Lineage Nodes:", list(dag.get("nodes", {}).keys()))

repro = ExperimentReproducer()
audit = repro.reproduce("EXP-RUN-001")
print("Reproduction Audit:", audit["match_status"])
