# %% [markdown]
# # Portfolio Research — Notebook 04: Mean-Variance Markowitz Optimization
#
# Maximizes expected return relative to portfolio variance parameter lambda.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('../../'))
import pandas as pd, numpy as np
from src.portfolio.optimizers import MeanVarianceOptimizer

symbols = ['AAPL', 'NVDA', 'MSFT']
exp_rets = pd.Series([0.03, 0.05, 0.02], index=symbols)
cov_df = pd.DataFrame([[0.04, 0.01, 0.005], [0.01, 0.09, 0.01], [0.005, 0.01, 0.025]], index=symbols, columns=symbols)
opt = MeanVarianceOptimizer(risk_aversion=2.5)
w = opt.optimize(exp_rets, cov_df)
print('Mean Variance Weights:', w.to_dict())
