# %% [markdown]
# # Quant AI Research — Notebook 06: Purged Time-Series Walk-Forward Validation & Embargoing
#
# Executes out-of-sample walk-forward validation with label overlap purging and embargo periods.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('../../'))
import pandas as pd
from src.research.robustness import RobustnessTester

df = pd.DataFrame({'price': range(100)})
train_df, test_df = RobustnessTester.purged_train_test_split(df, train_pct=0.7, purge_window=5, embargo_window=5)
print(f'Train size: {len(train_df)}, Test size: {len(test_df)}')
