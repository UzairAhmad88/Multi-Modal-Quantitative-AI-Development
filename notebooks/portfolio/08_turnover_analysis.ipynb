# %% [markdown]
# # Portfolio Research — Notebook 08: Turnover Control & Transaction Cost Drag
#
# Evaluates rebalance turnover penalties and transaction cost drag under market impact.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('../../'))
import pandas as pd
from src.portfolio.costs import CostModel

cm = CostModel(commission_bps=10.0, slippage_bps=5.0)
cost_info = cm.compute_trade_cost(trade_value=50000.0, daily_volume_value=10000000.0)
print('Cost Breakdown:', cost_info)
