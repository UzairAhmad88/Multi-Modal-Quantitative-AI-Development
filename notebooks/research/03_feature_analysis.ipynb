# %% [markdown]
# # Quant AI Research — Notebook 03: Feature Engineering & Correlation Structure
#
# Analyzes cross-feature collinearity, variance inflation factor (VIF), and stationarity.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('../../'))
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.randn(100, 5), columns=['momentum', 'volatility', 'sentiment', 'value', 'quality'])
corr = df.corr()
print('Correlation Matrix:\n', corr)
