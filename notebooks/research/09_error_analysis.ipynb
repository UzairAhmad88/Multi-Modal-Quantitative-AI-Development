# %% [markdown]
# # Quant AI Research — Notebook 09: Error Analysis, Drift Detection & Bootstrap Significance
#
# Analyzes false positive/negative failure regimes, Population Stability Index (PSI), and 95% bootstrap confidence intervals.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('../../'))
import pandas as pd
import numpy as np
from src.research.error_analysis import ErrorAnalyzer
from src.research.statistical_tests import StatisticalTester

rets = pd.Series(np.random.normal(0.0009, 0.011, 250))
st = StatisticalTester(rets)
ci = st.bootstrap_metrics(num_iterations=200)
print('Bootstrap 95% CIs:', ci)
