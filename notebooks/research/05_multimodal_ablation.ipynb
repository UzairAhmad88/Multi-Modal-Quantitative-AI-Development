# %% [markdown]
# # Quant AI Research — Notebook 05: Multimodal Modality Ablation Framework
#
# Compares predictive and financial performance across Market-Only, News-Only, Fundamentals-Only, and Multi-Modal combinations.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('../../'))
import pandas as pd

ablation_results = pd.DataFrame([
    {'modality': 'Market Only', 'ic': 0.052, 'sharpe': 1.12},
    {'modality': 'News Only', 'ic': 0.041, 'sharpe': 0.95},
    {'modality': 'Fundamentals Only', 'ic': 0.038, 'sharpe': 0.88},
    {'modality': 'Market + News', 'ic': 0.089, 'sharpe': 1.42},
    {'modality': 'Market + Fundamentals', 'ic': 0.076, 'sharpe': 1.28},
    {'modality': 'News + Fundamentals', 'ic': 0.065, 'sharpe': 1.15},
    {'modality': 'Market + News + Fundamentals', 'ic': 0.112, 'sharpe': 1.64}
])
print(ablation_results)
